# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv('Dateset_ODI+-+Dateset_ODI.csv')
pd.read_excel("CardioGoodFitness_Solutions_Excel_Workbook.xlsx")
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# ...

# %%
frequency=data[data['Winner']=='Australia'].shape[0]
print(frequency)
#Filter rows where 'team2' won the match
team2_wins=data[data['Winner']==['Team2']]
#count the number
num=len(team2_wins)
print(num)
# Out:
# 555
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 print(frequency)
#       3 #Filter rows where 'team2' won the match
# ----> 4 team2_wins=data[data['Winner']==['Team2']]
#       5 #count the number
#       6 num=len(team2_wins)
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\core\arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# ...
