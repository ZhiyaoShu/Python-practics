# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
bookdata=pd.read_csv('prog_book.csv')
df=pd.DataFrame(bookdata)

# %%
sns.histplot(data=df,x='Price', kde=True)
plt.yticks([0, 20, 40, 60, 80])
# Out:
# ([<matplotlib.axis.YTick at 0x175ede5d900>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80')])

# %%
sns.countplot(data=df, x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
colors=sns.color_palette('husl',len(df['Type'].unique()))
sns.stripplot(data=df,x='Type',y='Rating',palette=colors)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_21572\1822586679.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(data=df,x='Type',y='Rating',palette=colors)
# <Axes: xlabel='Type', ylabel='Rating'>

# %%
sns.boxplot(data=df,y='Rating')
# Out:
# <Axes: ylabel='Rating'>

# %%
sns.displot(data=df,x='Rating',kde=True)

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_21572\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >
